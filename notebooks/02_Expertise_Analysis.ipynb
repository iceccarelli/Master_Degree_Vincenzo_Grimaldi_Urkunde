# %% [markdown]
# # Expertise Analysis: My Master's Degree
#
# ## Business Administration and Engineering: Electrical Power Engineering (M.Sc. RWTH)
#
# In this notebook I look at the modules I completed during my Master's degree and explain how they built the knowledge I use every day as an electrical engineer at Deutsche Bahn InfraGO AG.
#
# The degree combined technical power systems with sustainability and business topics. This foundation helps me with renewable integration, IT safety and infrastructure modernisation.

# %%
import pandas as pd
import os

# Define path to the structured metadata
BASE_PATH = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
KEY_DETAILS_CSV = os.path.join(BASE_PATH, 'data', 'key_details.csv')

# Load the key details
key_details_df = pd.read_csv(KEY_DETAILS_CSV)

print("My Module Groups and Average Grades")
print("=" * 50)
groups = key_details_df[key_details_df['section'].str.contains('Module Group', case=False)]
print(groups[['detail_key', 'detail_value']].to_string(index=False))

print("\nSelected Key Modules")
key_modules = key_details_df[key_details_df['section'] == 'Key Module']
print(key_modules[['detail_key', 'detail_value']].to_string(index=False))

# %% [markdown]
# ### How My Studies Connect to My Daily Work
#
# The engineering modules (average 3.6) gave me practical knowledge in power systems, energy storage, electrical machines and grid stability.
#
# My specialisation in Sustainability and Corporations (average 2.4) taught me about sustainable finance, renewable integration and corporate responsibility.
#
# My Master thesis (grade 2.3) on cross-domain ontology and reinforcement learning for smart-grid cyber intelligence directly supports the IT safety and renewable energy work I do at Deutsche Bahn InfraGO AG.
#
# These topics help me contribute to secure and efficient rail infrastructure every day.

# %%
# Summary of core expertise areas
expertise = key_details_df[key_details_df['section'] == 'Key Facts']
print("\nCore Expertise Areas from My Degree")
print(expertise[['detail_key', 'detail_value']].to_string(index=False))

print("\nAll of these topics are directly applied in my current role at Deutsche Bahn InfraGO AG.")
